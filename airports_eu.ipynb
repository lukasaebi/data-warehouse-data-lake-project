# %% [markdown]
# # List of the busiest airports in Europe

# %%
import pandas as pd

# %%
# URL
url = "https://en.wikipedia.org/wiki/List_of_the_busiest_airports_in_Europe"

# %%
# Read table
tables = pd.read_html(url, header=None)

# Specifiy table
airports_table = tables[1]

print(airports_table.head(5))
# Out:
#   Rank 2023 Rank change 2022–2023          Country  \
#   Rank 2023 Rank change 2022–2023          Country
# 0         1                     1  United Kingdom1
# 1         2                     1          Turkey1
# 2         3                   NaN          France1
# 3         4                   NaN     Netherlands1
# 4         5                   NaN           Spain1
#
#                                 Airport City served        Passengers  \
#                                 Airport City served              2023
# 0                      Heathrow Airport      London     79,151,723[1]
# 1                      Istanbul Airport    Istanbul     76,236,980[3]
# 2             Charles de Gaulle Airport       Paris  67,421,316[5][6]
# 3            Amsterdam Airport Schiphol   Amsterdam     61,889,586[8]
# 4  Adolfo Suárez Madrid–Barajas Airport      Madrid    60,220,984[10]
#
#                   Change Δ 2023/2022
#              2022                  %      People
# 0   61,611,838[2]               28.5  17539885.0
# 1   64,486,178[4]               18.2  11750802.0
# 2   57,474,033[7]               17.3   9947283.0
# 3   52,472,188[9]               17.9   9417398.0
# 4  50,633,759[11]               18.9   9587225.0

# %%
airports_table.columns = airports_table.iloc[0]  


# Reset index
airports_table.reset_index(drop=True, inplace=True)

airports_table.head()
# Out:
# 0  1    1  United Kingdom1                      Heathrow Airport     London  \
# 0  1    1  United Kingdom1                      Heathrow Airport     London
# 1  2    1          Turkey1                      Istanbul Airport   Istanbul
# 2  3  NaN          France1             Charles de Gaulle Airport      Paris
# 3  4  NaN     Netherlands1            Amsterdam Airport Schiphol  Amsterdam
# 4  5  NaN           Spain1  Adolfo Suárez Madrid–Barajas Airport     Madrid
#
# 0     79,151,723[1]   61,611,838[2]  28.5  17539885.0
# 0     79,151,723[1]   61,611,838[2]  28.5  17539885.0
# 1     76,236,980[3]   64,486,178[4]  18.2  11750802.0
# 2  67,421,316[5][6]   57,474,033[7]  17.3   9947283.0
# 3     61,889,586[8]   52,472,188[9]  17.9   9417398.0
# 4    60,220,984[10]  50,633,759[11]  18.9   9587225.0

# %%
# Assuming airports_table is already cleaned and has correct columns
airports_table.columns = [
    "Rank", "Rank change", "Country", "Airport", "City served",
    "Passengers 2023", "Passengers 2022", "Change %", "Change People"
]

# Display the updated DataFrame
airports_table.head(5)
# Out:
#    Rank Rank change          Country                               Airport  \
# 0     1           1  United Kingdom1                      Heathrow Airport
# 1     2           1          Turkey1                      Istanbul Airport
# 2     3         NaN          France1             Charles de Gaulle Airport
# 3     4         NaN     Netherlands1            Amsterdam Airport Schiphol
# 4     5         NaN           Spain1  Adolfo Suárez Madrid–Barajas Airport
#
#   City served   Passengers 2023 Passengers 2022  Change %  Change People
# 0      London     79,151,723[1]   61,611,838[2]      28.5     17539885.0
# 1    Istanbul     76,236,980[3]   64,486,178[4]      18.2     11750802.0
# 2       Paris  67,421,316[5][6]   57,474,033[7]      17.3      9947283.0
# 3   Amsterdam     61,889,586[8]   52,472,188[9]      17.9      9417398.0
# 4      Madrid    60,220,984[10]  50,633,759[11]      18.9      9587225.0

# %%
# Drop the specified columns
columns_to_drop = ["Rank change", "Passengers 2022", "Change %", "Change People"]
airports_table = airports_table.drop(columns=columns_to_drop)

# Reset the index for a clean display
airports_table.reset_index(drop=True, inplace=True)

# %%
# Show table as DataFrame
airports_table.head(21)
# Out:
#     Rank          Country                                      Airport  \
# 0      1  United Kingdom1                             Heathrow Airport
# 1      2          Turkey1                             Istanbul Airport
# 2      3          France1                    Charles de Gaulle Airport
# 3      4     Netherlands1                   Amsterdam Airport Schiphol
# 4      5           Spain1         Adolfo Suárez Madrid–Barajas Airport
# 5      6         Germany1                    Frankfurt am Main Airport
# 6      7           Spain2  Josep Tarradellas Barcelona–El Prat Airport
# 7      8  United Kingdom2                              Gatwick Airport
# 8      9          Italy 1          Leonardo da Vinci–Fiumicino Airport
# 9     10         Germany2                               Munich Airport
# 10    11          Russia1           Sheremetyevo International Airport
# 11    12        Portugal1                               Lisbon Airport
# 12    13         Ireland1                               Dublin Airport
# 13    14          France2                                 Orly Airport
# 14    15           Spain3                    Palma de Mallorca Airport
# 15    16         Austria1                 Vienna International Airport
# 16    17     Switzerland1                               Zurich Airport
# 17    18          Greece1                 Athens International Airport
# 18    19  United Kingdom3                           Manchester Airport
# 19    20  United Kingdom4                             Stansted Airport
# 20    21         Denmark1                           Copenhagen Airport
#
#           City served     Passengers 2023
# 0              London       79,151,723[1]
# 1            Istanbul       76,236,980[3]
# 2               Paris    67,421,316[5][6]
# 3           Amsterdam       61,889,586[8]
# 4              Madrid      60,220,984[10]
# 5           Frankfurt      59,359,539[12]
# 6           Barcelona      49,909,544[10]
# 7              London  40,897,656[15][16]
# 8                Rome  40,545,240[18][19]
# 9              Munich      37,037,070[20]
# 10             Moscow      36,600,000[23]
# 11             Lisbon      33,649,000[15]
# 12             Dublin      33,522,493[26]
# 13              Paris    32,294,167[5][6]
# 14  Palma de Mallorca      31,105,987[10]
# 15             Vienna      29,533,186[28]
# 16             Zürich      28,885,506[30]
# 17             Athens      28,174,150[32]
# 18         Manchester      28,108,238[34]
# 19             London      27,965,262[34]
# 20         Copenhagen      26,765,393[37]

# %%
# Save table as csv
airports_table.to_csv("busiest_airports_in_europe.csv", index=False)
